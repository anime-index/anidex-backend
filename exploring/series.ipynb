# %%
import pandas as pd

series = pd.read_json('../data/series.json')

# %%
series['value'] = series.score.rank(ascending=False) + series.popularity.rank(ascending=False)

# %%
series.sort_values('value', inplace=True)

# %%
series.index
# Out:
# Int64Index([11192,  4631,  8272,  4080,  5297,  1003,  7073,   980, 11947,
#              6335,
#             ...
#             15566, 15567, 15568, 15569, 15571, 15572, 15573, 15574, 15575,
#             15576],
#            dtype='int64', length=15577)

# %%
series['position'] = range(1, series.shape[0]+1)

series
# Out:
#        series_id                                       title  popularity  \
# 11192      11192            Fullmetal Alchemist: Brotherhood     2425872
# 4631        4631                      Hunter x Hunter (2011)     1884692
# 8272        8272                              Kimi no Na wa.     1916118
# 4080        4080                                 Steins;Gate     1909826
# 5297        5297                          Shingeki no Kyojin     2799964
# ...          ...                                         ...         ...
# 15572      15572                    Keke Xiao Ai Luyou Xilie           0
# 15573      15573                   Keke Xiao Ai Xinchun Teji           0
# 15574      15574  “Keke Xiao Ai”2015 Nian Chunjie Tebie Pian           0
# 15575      15575     Keke Xiao Ai Ertong Yingji Anquan Xilie           0
# 15576      15576        Keke Xiao Ai Zhi Shijie Xuanchuan Ri           0
#
#           score                                          image_url  episodes  \
# 11192  9.170000  https://cdn.myanimelist.net/images/anime/1223/...        64
# 4631   9.080000  https://cdn.myanimelist.net/images/anime/11/33...       148
# 8272   8.930000  https://cdn.myanimelist.net/images/anime/5/870...         1
# 4080   8.900681  https://cdn.myanimelist.net/images/anime/5/731...        26
# 5297   8.676964  https://cdn.myanimelist.net/images/anime/10/47...        75
# ...         ...                                                ...       ...
# 15572       NaN  https://cdn.myanimelist.net/img/sp/icon/apple-...        26
# 15573       NaN  https://cdn.myanimelist.net/img/sp/icon/apple-...        10
# 15574       NaN  https://cdn.myanimelist.net/img/sp/icon/apple-...         1
# 15575       NaN  https://cdn.myanimelist.net/img/sp/icon/apple-...        28
# 15576       NaN  https://cdn.myanimelist.net/img/sp/icon/apple-...         9
#
#        seasons                                           synopsis  value  \
# 11192        1  "In order for something to be obtained, someth...    4.0
# 4631         1  Hunter x Hunter is set in a world where Hunter...   13.0
# 8272         1  Mitsuha Miyamizu, a high school girl, yearns t...   14.0
# 4080         3  The self-proclaimed mad scientist Rintarou Oka...   16.0
# 5297         5  Centuries ago, mankind was slaughtered to near...   18.0
# ...        ...                                                ...    ...
# 15572        1                                               None    NaN
# 15573        1                                               None    NaN
# 15574        1                    Chinese special of Keke Xiao Ai    NaN
# 15575        1                                               None    NaN
# 15576        1                                               None    NaN
#
#        position
# 11192         1
# 4631          2
# 8272          3
# 4080          4
# 5297          5
# ...         ...
# 15572     15573
# 15573     15574
# 15574     15575
# 15575     15576
# 15576     15577
#
# [15577 rows x 10 columns]
